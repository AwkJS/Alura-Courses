# %%
import pandas as pd

notas = pd.read_csv("ml-latest-small/ratings.csv")
notas.columns = ["usuarioId", "filmeId", "nota", "momento"] #alterando o nome das colunas
notas.head() # 5 primeiros elementos
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].value_counts() #quantas vezes o dado se repetiu
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print("Media:", notas['nota'].mean()) #média de todas as notas
print("Mediana:", notas['nota'].median()) #mediana
# Out:
# Media: 3.501556983616962
# Mediana: 3.5

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns
sns.boxplot(data=notas.nota)
#Metade das notas são entre 3 e 4
# Out:
# <AxesSubplot:>
